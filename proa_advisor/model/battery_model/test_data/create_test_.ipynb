# %%
import numpy as np
import pandas as pd

# %%
output_file_name = "test_data.csv"

# %%
header = ["counter", "timediff_us", "ch0", "ch1", "ch2", "ch3", "ch4", "ch5", "ch6", "ch7"]
ave_time_diff_us = 850
counter = 0
total_test_points = 10000000

# CH0: MPPT
# CH1: LOAD
# CH2: B1
# CH3: B2
# CH4: 0
# CH5: 0
# CH6: B1_V
# CH7: B2_V

data = []

# %%
for i in range(0, total_test_points):
    rand_time = np.random.normal(ave_time_diff_us, 50)
